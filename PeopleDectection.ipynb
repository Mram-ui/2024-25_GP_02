# %% [markdown]
# Yolov8 for People detection

# %%
#! pip install ultralytics

# %%
from ultralytics import YOLO

# %% [markdown]
# import cv2
# from ultralytics import YOLO
# import matplotlib.pyplot as plt

# %%
! pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\basha\appdata\local\programs\python\python311\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\basha\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.25.1)
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8n.pt")

# %%
cap = cv2.VideoCapture(0)

# Check if the webcam is opened correctly
if not cap.isOpened():
    print("Error: Could not open camera.")
else:
    while True:
        # Capture each frame from the webcam
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame")
            break

        # Use the model to detect objects
        results = model(frame)

        # Visualize the detection results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame in a window
        cv2.imshow("YOLOv8 Detection", annotated_frame)

        # Break the loop when 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the webcam and close windows
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 210.1ms
# Speed: 5.0ms preprocess, 210.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.6ms
# Speed: 7.6ms preprocess, 183.6ms inference, 20.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 389.9ms
# Speed: 6.0ms preprocess, 389.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 234.2ms
# Speed: 11.9ms preprocess, 234.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.1ms
# Speed: 2.6ms preprocess, 189.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 197.8ms
# Speed: 9.2ms preprocess, 197.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 160.6ms
# Speed: 7.3ms preprocess, 160.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 168.9ms
# Speed: 8.8ms preprocess, 168.9ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.1ms
# Speed: 4.8ms preprocess, 209.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.0ms
# Speed: 2.0ms preprocess, 200.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 319.9ms
# Speed: 14.7ms preprocess, 319.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 185.6ms
# Speed: 4.1ms preprocess, 185.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 254.6ms
# Speed: 5.4ms preprocess, 254.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.6ms
# Speed: 1.7ms preprocess, 142.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 152.3ms
# Speed: 2.1ms preprocess, 152.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.2ms
# Speed: 2.5ms preprocess, 132.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Speed: 1.6ms preprocess, 124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.3ms
# Speed: 4.5ms preprocess, 123.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 136.0ms
# Speed: 0.0ms preprocess, 136.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 128.1ms
# Speed: 0.0ms preprocess, 128.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.1ms
# Speed: 4.1ms preprocess, 131.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.0ms
# Speed: 1.0ms preprocess, 132.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.2ms
# Speed: 4.1ms preprocess, 120.2ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 125.2ms
# Speed: 4.1ms preprocess, 125.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 135.2ms
# Speed: 0.0ms preprocess, 135.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 144.8ms
# Speed: 0.0ms preprocess, 144.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 390.9ms
# Speed: 29.5ms preprocess, 390.9ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 369.4ms
# Speed: 0.0ms preprocess, 369.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 277.8ms
# Speed: 12.7ms preprocess, 277.8ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person,